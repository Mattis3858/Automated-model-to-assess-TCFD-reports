# %%
import pandas as pd

df1 = pd.read_excel("data/tcfd第四層接露指引 - 加上第一層指標及關鍵字.xlsx")
df2 = pd.read_excel("data/tcfd第四層揭露指引.xlsx")

# %%
df1
# Out:
#              類別                                     第四層(TCFD) 揭露指引
# 0       G-1-1_1  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，定期報告氣...
# 1       G-1-1_2  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，報告氣候相...
# 2       G-1-2_3  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督和指導...
# 3       G-1-2_4  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督重要資...
# 4       G-1-3_5  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會或其所屬和/或指派之委員會如何監督風...
# ...         ...                                                ...
# 3769   S-3-3_44  京城銀行以綠色金融體系網路（The Network for Greening the Fin...
# 3770  MT-3-2_79  2023年\n2025年\n2030年\n服務數位化-碳標籤\n人壽、銀行、產險承諾60%主...
# 3771   S-3-1_39  情境\n情境一\n情境二\n情境三\nNGFS 情境\nNet Zero 2050\nDel...
# 3772   S-3-2_40                 情境分析結果\n預期損失/稅前損益\n註：稅前損益為2022年底之值
# 3773   S-2-6_37  淨零規劃\n面對國際淨零排放趨勢，我們分別從自身營運與投融資部位著手，對於降低自身營運碳排放...
#
# [3774 rows x 2 columns]

# %%
df2
# Out:
#         Label                                         Definition
# 0     G-1-1_1            公司是否描述向董事會和/或董事會下設委員會，定期報告氣候相關風險與機會之流程？
# 1     G-1-1_2              公司是否描述向董事會和/或董事會下設委員會，報告氣候相關風險與機會之頻率？
# 2     G-1-2_3  公司是否描述董事會和/或董事會下設委員會，在監督和指導策略、重要行動計畫、風險管理政策、年度...
# 3     G-1-2_4  公司是否描述董事會和/或董事會下設委員會，在監督重要資本支出、企業收購和撤資時，考量氣候相關...
# 4     G-1-3_5              公司是否描述董事會或其所屬和/或指派之委員會如何監督風險與機會目標之實現？
# ..        ...                                                ...
# 86  MT-3-2_78                          公司設定目標時，是否有描述衡量進度情況的基準年份？
# 87  MT-3-2_79                      公司設定目標時，是否有描述評估目標進展情況的重要績效指標？
# 88  MT-3-3_80                                公司是否依總體或業務劃分揭露中期目標？
# 89  MT-3-3_81                                公司是否依總體或業務劃分揭露長期目標？
# 90  MT-3-4_82                             公司是否有計算目標和計量方法不易鑑別之描述？
#
# [91 rows x 2 columns]

# %%
filtered_df = df1[df1['類別'].isin(df2['Label'])]

filtered_df
# Out:
#              類別                                     第四層(TCFD) 揭露指引
# 0       G-1-1_1  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，定期報告氣...
# 1       G-1-1_2  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，報告氣候相...
# 2       G-1-2_3  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督和指導...
# 3       G-1-2_4  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督重要資...
# 4       G-1-3_5  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會或其所屬和/或指派之委員會如何監督風...
# ...         ...                                                ...
# 3769   S-3-3_44  京城銀行以綠色金融體系網路（The Network for Greening the Fin...
# 3770  MT-3-2_79  2023年\n2025年\n2030年\n服務數位化-碳標籤\n人壽、銀行、產險承諾60%主...
# 3771   S-3-1_39  情境\n情境一\n情境二\n情境三\nNGFS 情境\nNet Zero 2050\nDel...
# 3772   S-3-2_40                 情境分析結果\n預期損失/稅前損益\n註：稅前損益為2022年底之值
# 3773   S-2-6_37  淨零規劃\n面對國際淨零排放趨勢，我們分別從自身營運與投融資部位著手，對於降低自身營運碳排放...
#
# [3774 rows x 2 columns]

# %%
unique_label_count = filtered_df["類別"].nunique()
print("Unique labels count:", unique_label_count)
# Out:
# Unique labels count: 91

# %%
filtered_df.columns = ["Label", "Definition"]
filtered_df = filtered_df.dropna(subset=["Label", "Definition"])
filtered_df
# Out:
#           Label                                         Definition
# 0       G-1-1_1  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，定期報告氣...
# 1       G-1-1_2  董事會對氣候相關風險與機會的監督情況。公司是否描述向董事會和/或董事會下設委員會，報告氣候相...
# 2       G-1-2_3  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督和指導...
# 3       G-1-2_4  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會和/或董事會下設委員會，在監督重要資...
# 4       G-1-3_5  董事會對氣候相關風險與機會的監督情況。公司是否描述董事會或其所屬和/或指派之委員會如何監督風...
# ...         ...                                                ...
# 3769   S-3-3_44  京城銀行以綠色金融體系網路（The Network for Greening the Fin...
# 3770  MT-3-2_79  2023年\n2025年\n2030年\n服務數位化-碳標籤\n人壽、銀行、產險承諾60%主...
# 3771   S-3-1_39  情境\n情境一\n情境二\n情境三\nNGFS 情境\nNet Zero 2050\nDel...
# 3772   S-3-2_40                 情境分析結果\n預期損失/稅前損益\n註：稅前損益為2022年底之值
# 3773   S-2-6_37  淨零規劃\n面對國際淨零排放趨勢，我們分別從自身營運與投融資部位著手，對於降低自身營運碳排放...
#
# [3746 rows x 2 columns]

# %%
unique_label_count = filtered_df["Label"].nunique()
print("Unique labels count:", unique_label_count)
# Out:
# Unique labels count: 91

# %%
filtered_df.to_csv("data/filtered_揭露指引.csv", index=False, encoding='utf-8')
